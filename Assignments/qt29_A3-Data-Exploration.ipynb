# %% [markdown]
# # Assignment 3: Data Exploration
# ```
# Course: ENV 700 - Environmental Data Exploration
# Author: Lam Thieu
# Date: Fall 2026
# ```
#
# This notebook accompanies the Python lessons on **Data Exploration**, the first stage in the data analytics pipeline: **exploration, wrangling, analysis, and visualization**.

# %% [markdown]
# Use this notebook to explore the `NEON_NIWO_Litter_massdata_2016-26_raw.csv` dataset.
# 1. Data Provenance: Answer questions regarding the dataset by referring to its metadata document.
# 1. Set up your notebook: Import packages, set data paths, set file paths
# 1. Import the dataset into a dataframe and inspect its properties
# 1. Reassign data types as needed
# 1. Examine the data for any missing values
# 1. Examine the distribution of values in the dataset, noting any extreme or unusual values
# 1. Explore any patterns in the data

# %% [markdown]
# ---
# ## 1. Data Provenance

# %% [markdown]
# The Niwot Ridge litter and woody debris dataset was collected from the National Ecological Observatory Network, which collectively includes 81 aquatic and terrestrial sites across 20 ecoclimatic domains. 32 of these sites sample forest litter and woody debris, and we will focus on the Niwot Ridge long-term ecological research (LTER) station in Colorado.
#
# Why might we be interested in studying litter and woody debris that falls to the ground in forests? Feel free to do a brief internet search if you feel you need more background information. (AI is allowed here, but put answers in your own words.)

# %% [markdown]
# >Answer: Litterfall is how carbon fixed in aboveground biomass gets delivered to the forest floor, where it decomposes which is the same process as composting, just unmanaged. Most of that carbon respires back to the atmosphere as CO₂, and only the fraction that resists decomposition stabilizes into belowground soil organic matter, which is the part that counts as sequestration.

# %% [markdown]
# ---
# ## 2. Set up your Python session

# %% [markdown]
# Load the necessary packages, check your current working directory, and import the Niwot Ridge NEON litter and woody debris dataset: `NEON_NIWO_Litter_massdata_2016-26_raw.csv`
#
# Name  dataframes `Litter`.
#
# **Be sure to:**
#
# - Use `pathlib.Path` to specify project-relative paths to your datasets.
# - Convert appropriate character-based columns to the Pandas `category` dtype.
# - Print or otherwise confirm the paths to each filename.
# - Display the first 5 rows of each dataframe.

# %% [markdown]
# ### ✅ 2.1 Import packages
# * Load the pathlib Path object and the Pandas package into your coding environnment

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ### ✅ 2.2 Set project folders using relative paths
# * Create two Path variables, one set to your project's root folder and another to the raw data folder.
# * Display the the values of these two variables in your notebook.

# %%
root_fldr = Path.cwd().parent
raw_fldr = root_fldr / 'data' / 'raw'
processed_fldr = root_fldr / 'data'/ 'processed'

# %% [markdown]
# ### ✅ 2.3 Set a path to the raw data file
# * Create a Path variable pointing to the `NEON_NIWO_Litter_massdata_2016-26_raw.csv` file.
# * Confirm that the file exists at the path specified.

# %%
raw_file = raw_fldr / "NEON_NIWO_Litter_massdata_2016-26_raw.csv"

# %% [markdown]
# ### ✅ 2.4 Import the data
# * Import the CSV file as a dataframe named `Litter`.
# * Display the first 5 rows of the dataframe.

# %%
Litter = pd.read_csv(raw_file)
Litter.head(5)
# Out:
#                                     uid          namedLocation domainID  \
# 0  907e663c-b899-4801-b477-d5effa28bd7b  NIWO_047.basePlot.ltr      D13
# 1  8c01e181-8bfb-4f66-ab4e-e76fd291ca48  NIWO_047.basePlot.ltr      D13
# 2  8a69528e-5d64-4601-ae19-3e2ae57eb20c  NIWO_047.basePlot.ltr      D13
# 3  154c966e-e66e-4450-b7ba-c43733562863  NIWO_061.basePlot.ltr      D13
# 4  a8887a79-49ea-4a6c-bb9b-2004b7474287  NIWO_062.basePlot.ltr      D13
#
#   siteID    plotID        trapID   weighDate     setDate collectDate  \
# 0   NIWO  NIWO_047  NIWO_047_197  2016-06-22  2015-09-29  2016-06-16
# 1   NIWO  NIWO_047  NIWO_047_197  2016-06-22  2015-09-29  2016-06-16
# 2   NIWO  NIWO_047  NIWO_047_197  2016-06-22  2015-09-29  2016-06-16
# 3   NIWO  NIWO_061  NIWO_061_169  2016-06-22  2015-09-29  2016-06-16
# 4   NIWO  NIWO_062  NIWO_062_050  2016-06-22  2015-09-29  2016-06-16
#
#             eventID  ...                      massSampleID  \
# 0  LTR.2016.NIWO.01  ...  NEON.LTR.NIWO047197.20160616.FLR
# 1  LTR.2016.NIWO.01  ...  NEON.LTR.NIWO047197.20160616.LVS
# 2  LTR.2016.NIWO.01  ...  NEON.LTR.NIWO047197.20160616.NDL
# 3  LTR.2016.NIWO.01  ...  NEON.LTR.NIWO061169.20160616.LVS
# 4  LTR.2016.NIWO.01  ...  NEON.LTR.NIWO062050.20160616.OTH
#
#   samplingProtocolVersion biogeoSample functionalGroup  dryMass qaDryMass  \
# 0       NEON.DOC.001710vE            N         Flowers     0.01         N
# 1       NEON.DOC.001710vE            N          Leaves     0.00         N
# 2       NEON.DOC.001710vE            N         Needles     0.54         N
# 3       NEON.DOC.001710vE            N          Leaves     0.00         N
# 4       NEON.DOC.001710vE            N           Other     0.58         N
#
#                 remarks             measuredBy   publicationDate       release
# 0                   NaN  jlinden@field-ops.org  20251204T230619Z  RELEASE-2026
# 1  no sample to collect  jlinden@field-ops.org  20251204T230619Z  RELEASE-2026
# 2                   NaN  jlinden@field-ops.org  20251204T230619Z  RELEASE-2026
# 3  no sample to collect  jlinden@field-ops.org  20251204T230619Z  RELEASE-2026
# 4                   NaN  jlinden@field-ops.org  20251204T230619Z  RELEASE-2026
#
# [5 rows x 25 columns]

# %% [markdown]
# ### ✅ 2.5 Examine your dataframe
# * From just looking at the data, enter a single field name that appears to fit the indicated description. If there are none that fit that column, just enter "None".

# %% [markdown]
# > List a **categorical** column: namedLocation, domainID, siteID, plotID, trapID, eventID, sampleCondition, samplingProtocolVersion, functionalGroup, release, measuredBy, publicationDate

# %% [markdown]
# > List a **date** column: weighDate, setDate, collectDate, ovenStartDate, ovenEndDate

# %% [markdown]
# > List a **floating point** column: dryMass

# %% [markdown]
# > List a **string** column: uid, fieldSampleID, massSampleID, remarks

# %% [markdown]
# > List a **Boolean** column: bioGeosample, qaDryMass

# %% [markdown]
# ---
# ## 3. Explore the structure of your dataframe
# * Use the most appropriate dataframe property or method for each question.

# %% [markdown]
# #### ✅ 3.1 Reveal the dimensions (# of rows and columns) of your dataframe

# %%
Litter.shape
# Out:
# (4443, 25)

# %% [markdown]
# #### ✅ 3.2 List the names of the columns in the dataframe.

# %%
Litter.columns
# Out:
# Index(['uid', 'namedLocation', 'domainID', 'siteID', 'plotID', 'trapID',
#        'weighDate', 'setDate', 'collectDate', 'eventID', 'ovenStartDate',
#        'ovenEndDate', 'fieldSampleID', 'sampleCondition', 'samplePrepMethod',
#        'massSampleID', 'samplingProtocolVersion', 'biogeoSample',
#        'functionalGroup', 'dryMass', 'qaDryMass', 'remarks', 'measuredBy',
#        'publicationDate', 'release'],
#       dtype='str')

# %% [markdown]
# #### ✅ 3.3 Display information about each column including its name, its datatype, and how many non-null values it contains.

# %%
Litter.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4443 entries, 0 to 4442
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uid                      4443 non-null   str
#  1   namedLocation            4443 non-null   str
#  2   domainID                 4443 non-null   str
#  3   siteID                   4443 non-null   str
#  4   plotID                   4443 non-null   str
#  5   trapID                   4443 non-null   str
#  6   weighDate                3746 non-null   str
#  7   setDate                  4443 non-null   str
#  8   collectDate              4443 non-null   str
#  9   eventID                  4443 non-null   str
#  10  ovenStartDate            3936 non-null   str
#  11  ovenEndDate              3936 non-null   str
#  12  fieldSampleID            4443 non-null   str
#  13  sampleCondition          2669 non-null   str
#  14  samplePrepMethod         0 non-null      float64
#  15  massSampleID             4443 non-null   str
#  16  samplingProtocolVersion  4370 non-null   str
#  17  biogeoSample             4370 non-null   str
#  18  functionalGroup          4443 non-null   str
#  19  dryMass                  4443 non-null   float64
#  20  qaDryMass                4443 non-null   str
#  21  remarks                  165 non-null    str
#  22  measuredBy               2507 non-null   str
#  23  publicationDate          4443 non-null   str
#  24  release                  4443 non-null   str
# dtypes: float64(2), str(23)
# memory usage: 867.9 KB

# %% [markdown]
# #### ✅ 3.4 Show summary statistics for each numeric column in the dataframe

# %%
Litter.describe()
# Out:
#        samplePrepMethod      dryMass
# count               0.0  4443.000000
# mean                NaN     1.247968
# std                 NaN     4.530086
# min                 NaN     0.000000
# 25%                 NaN     0.000000
# 50%                 NaN     0.010000
# 75%                 NaN     0.410000
# max                 NaN   145.250000

# %% [markdown]
# #### ✅ 3.5 Describe one issue with this dataset that is worth mentioning before proceeding with its analysis.

# %% [markdown]
# > Answer: About a quarter of the dryMass values are exactly zero, and the median is 0.01 against a mean of 1.25. Those zeros aren't small measurements because the remarks field on several of them reads "no sample to collect," meaning the trap was empty. So the column mixes real weights with recorded absences, and nothing separates the two except a remarks field that is 96% blank. Any mean or group comparison run on dryMass is averaging measurements together with non-events, which drags every group's center toward zero and understates actual litter mass.

# %% [markdown]
# ---
# ## 4. Reassign data types

# %% [markdown]
# #### ✅ 4.1. List the data types of each column

# %%
Litter.dtypes
# Out:
# uid                            str
# namedLocation                  str
# domainID                       str
# siteID                         str
# plotID                         str
# trapID                         str
# weighDate                      str
# setDate                        str
# collectDate                    str
# eventID                        str
# ovenStartDate                  str
# ovenEndDate                    str
# fieldSampleID                  str
# sampleCondition                str
# samplePrepMethod           float64
# massSampleID                   str
# samplingProtocolVersion        str
# biogeoSample                   str
# functionalGroup                str
# dryMass                    float64
# qaDryMass                      str
# remarks                        str
# measuredBy                     str
# publicationDate                str
# release                        str
# dtype: object

# %% [markdown]
# #### ✅ 4.2 Convert the `plotID` column's data type from a "string" to a "category"

# %%
Litter["plotID"] = Litter["plotID"].astype("category")
Litter.dtypes
# Out:
# uid                             str
# namedLocation                   str
# domainID                        str
# siteID                          str
# plotID                     category
# trapID                          str
# weighDate                       str
# setDate                         str
# collectDate                     str
# eventID                         str
# ovenStartDate                   str
# ovenEndDate                     str
# fieldSampleID                   str
# sampleCondition                 str
# samplePrepMethod            float64
# massSampleID                    str
# samplingProtocolVersion         str
# biogeoSample                    str
# functionalGroup                 str
# dryMass                     float64
# qaDryMass                       str
# remarks                         str
# measuredBy                      str
# publicationDate                 str
# release                         str
# dtype: object

# %% [markdown]
# #### ✅ 4.3 Convert the `collectDate` column's data type from a "string" to a "datetime"
# * Be sure to set the date format explicitly.

# %%
Litter['collectDate'] = pd.to_datetime(Litter['collectDate'],format='%Y-%m-%d')
Litter.dtypes
# Out:
# uid                                   str
# namedLocation                         str
# domainID                              str
# siteID                                str
# plotID                           category
# trapID                                str
# weighDate                             str
# setDate                               str
# collectDate                datetime64[us]
# eventID                               str
# ovenStartDate                         str
# ovenEndDate                           str
# fieldSampleID                         str
# sampleCondition                       str
# samplePrepMethod                  float64
# massSampleID                          str
# samplingProtocolVersion               str
# biogeoSample                          str
# functionalGroup                       str
# dryMass                           float64
# qaDryMass                             str
# remarks                               str
# measuredBy                            str
# publicationDate                       str
# release                               str
# dtype: object

# %% [markdown]
# #### ✅ 4.4 Show the updated datatypes

# %%
Litter.dtypes
# Out:
# uid                                   str
# namedLocation                         str
# domainID                              str
# siteID                                str
# plotID                           category
# trapID                                str
# weighDate                             str
# setDate                               str
# collectDate                datetime64[us]
# eventID                               str
# ovenStartDate                         str
# ovenEndDate                           str
# fieldSampleID                         str
# sampleCondition                       str
# samplePrepMethod                  float64
# massSampleID                          str
# samplingProtocolVersion               str
# biogeoSample                          str
# functionalGroup                       str
# dryMass                           float64
# qaDryMass                             str
# remarks                               str
# measuredBy                            str
# publicationDate                       str
# release                               str
# dtype: object

# %% [markdown]
# #### ✅ 4.5 Reimport the CSV setting the following data types, again saving as a dataframe named `Litter`
# * `siteID`, `plotID`, `trapID`, and `functionalGroup` should be imported as categories.
# * `weighDate`, `setDate`, and `collectDate` should be imported as dates. Set the date format explicitly.
# * After importing show the dtypes of the dataframe.

# %%
Litter = pd.read_csv(
    raw_file,
    dtype={
        "siteID": "category",
        "plotID": "category",
        "trapID": "category",
        "functionalGroup": "category",
    },
    parse_dates=["weighDate", "setDate", "collectDate"],
    date_format="%Y-%m-%d"
)

Litter.dtypes
# Out:
# uid                                   str
# namedLocation                         str
# domainID                              str
# siteID                           category
# plotID                           category
# trapID                           category
# weighDate                  datetime64[us]
# setDate                    datetime64[us]
# collectDate                datetime64[us]
# eventID                               str
# ovenStartDate                         str
# ovenEndDate                           str
# fieldSampleID                         str
# sampleCondition                       str
# samplePrepMethod                  float64
# massSampleID                          str
# samplingProtocolVersion               str
# biogeoSample                          str
# functionalGroup                  category
# dryMass                           float64
# qaDryMass                             str
# remarks                               str
# measuredBy                            str
# publicationDate                       str
# release                               str
# dtype: object

# %% [markdown]
# ---
# ## 5. Examine the data for missing values

# %% [markdown]
# #### ✅ 5.1 Report the percentage of records in each column that are missing.
# * Present this as a table of all columns listed in descending order of missing values, i.e. the field with the highest percentage of missing values should be listed first.

# %%
missing_percent = Litter.isna().mean().sort_values(ascending=False)*100
missing_percent
# Out:
# samplePrepMethod           100.000000
# remarks                     96.286293
# measuredBy                  43.574162
# sampleCondition             39.927977
# weighDate                   15.687598
# ovenEndDate                 11.411209
# ovenStartDate               11.411209
# biogeoSample                 1.643034
# samplingProtocolVersion      1.643034
# collectDate                  0.000000
# setDate                      0.000000
# trapID                       0.000000
# plotID                       0.000000
# domainID                     0.000000
# siteID                       0.000000
# namedLocation                0.000000
# uid                          0.000000
# massSampleID                 0.000000
# fieldSampleID                0.000000
# eventID                      0.000000
# functionalGroup              0.000000
# qaDryMass                    0.000000
# dryMass                      0.000000
# publicationDate              0.000000
# release                      0.000000
# dtype: float64

# %% [markdown]
# #### ✅ 5.2 Compare the mean dry mass for all records vs just records that have a known sample condition value
# * Create a new dataframe that eliminates rows that are missing values in the `sampleCondition` column.
# * Compute the mean of values in the `dryMass` column for all records.
# * Compute the mean of values in the `dryMass` column for just the records having a known sample condition value

# %%
Litter_update = Litter.dropna(subset=["sampleCondition"]).copy()

print("Original shape:", Litter.shape)
print("Rows with sampleCondition present:", Litter_update.shape)


mean_litter = Litter["dryMass"].mean()
print("Mean all litter:", mean_litter)

mean_litter_update = Litter_update["dryMass"].mean()
print("Mean update litter:", mean_litter_update)
# Out:
# Original shape: (4443, 25)
# Rows with sampleCondition present: (2669, 25)
# Mean all litter: 1.247968039612874
# Mean update litter: 1.325412888722368

# %% [markdown]
# ---
# ## 6. Examine the distibution of values

# %% [markdown]
# ### ✅ 6.1 Create a plot showing how many records occur in each functional group
# * Functional groups = '*Flowers*', '*Leaves*', '*Needles*', etc.
# * Sort the bars in order from least to greatest number of records.

# %%
Litter['functionalGroup'].value_counts().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='functionalGroup'>

# %% [markdown]
# ### ✅ 6.2 Examine the distribution of dry mass for each functional group
# * Create a box plot of dry mass showing a separate box for each functional group.
# * TIP:
#     - Add the argument `vert=False` to rotate the plot 90 degrees for easier reading.
#     - Also set the figure width x height to 14 x 5, also to make it more informative.

# %%
Litter[['functionalGroup','dryMass']].plot(kind='box',by='functionalGroup',vert=False, figsize=(14,5))
# Out:
# dryMass    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# #### 🔸Interpretation
# * Which functional group has the highest median dry mass?

# %% [markdown]
# >Answer: Needles, it seems to has the highest median.

# %% [markdown]
# * Which functional group has the highest measured dry mass?

# %% [markdown]
# > Answer: Twigs/branches because you can see the highest measured is the one that is pass 140 in term of drymass.

# %% [markdown]
# ### ✅ 6.3 Repeat the same plot but omitting the outliers
# * Include the argument `showfliers=False` to omit outliers.

# %%
Litter[['functionalGroup','dryMass']].plot(kind='box',by='functionalGroup',vert=False, figsize=(14,5), showfliers=False)
# Out:
# dryMass    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# #### 🔸Interpretation
# * Which functional group has the largest inter-quartile range?

# %% [markdown]
# > Answer: It has to be needles as you can see it has the longest line and the biggest box out of all the functional group.

# %% [markdown]
# ## ✳️ Submission
# * Check that you have answered all the questions asked.
# * Restart your notebook and then run all code cells.
# * Stage and commit the notebook to Git, push to GitHub
# * Export your notebook to an HTML document
#     - From the `...` item in the notebook menu, select Export, thn HTML
# * Submit the PDF to Canvas.
